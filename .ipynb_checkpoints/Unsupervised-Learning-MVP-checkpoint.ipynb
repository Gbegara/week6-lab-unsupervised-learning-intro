# %%
import pandas as pd

# %% [markdown]
# # Importing Songs and features file

# %%
df = pd.read_csv('song_and_features.csv')

# %%
df= df.drop(['Unnamed: 0'], axis=1)

# %%
df
# Out:
#                             title          artist  duration_ms  explicit  \
# 0                              2K     Nosaj Thing       152560     False
# 1                 4 Billion Souls       The Doors       197706     False
# 2                4 Minute Warning       Radiohead       244284     False
# 3                       7 Element           Vitas       249939     False
# 4                        #9 Dream          R.E.M.       278320     False
# ...                           ...             ...          ...       ...
# 9913  London Calling - Remastered       The Clash       200480     False
# 9914                    Low Rider             War       191560     False
# 9915                       Flower            Moby       206293     False
# 9916           Brighter Than Gold  The Cat Empire       200293     False
# 9917     Fury of the Storm - Live     DragonForce       409013     False
#
#       popularity                                   uri  danceability  energy  \
# 0              0  spotify:track:33xMbeHzmWd6Od0BmLZEUs         0.310   0.445
# 1             22  spotify:track:3UnyplmZaq547hwsfOR5yy         0.419   0.565
# 2              0  spotify:track:1w8QCSDH4QobcQeT4uMKLm         0.354   0.302
# 3              0  spotify:track:7J9mBHG4J2eIfDAv5BehKA         0.727   0.785
# 4              4  spotify:track:1VZedwJj1gyi88WFRhfThb         0.571   0.724
# ...          ...                                   ...           ...     ...
# 9913          69  spotify:track:5jzma6gCzYtKB1DbEwFZKH         0.651   0.801
# 9914           0  spotify:track:2fmMPJb5EzZCx8BcNJvVk4         0.811   0.647
# 9915          53  spotify:track:60rIdEPDrzyLiLC0icp3xz         0.686   0.610
# 9916          44  spotify:track:0sEm1ld0V8YTCPcjPVfIsc         0.711   0.718
# 9917          11  spotify:track:4JPE3Q7vuFa6UFoduMgZm2         0.323   0.997
#
#       key  loudness  mode  speechiness  acousticness  instrumentalness  \
# 0       7   -13.355     0       0.0863       0.09400          0.067800
# 1       5   -11.565     1       0.0347       0.13700          0.337000
# 2       9   -13.078     1       0.0326       0.59000          0.070900
# 3       5    -6.707     0       0.0603       0.32500          0.126000
# 4       0    -5.967     1       0.0260       0.02310          0.003110
# ...   ...       ...   ...          ...           ...               ...
# 9913    0    -7.340     1       0.0514       0.12300          0.000000
# 9914    0   -10.989     1       0.0498       0.08230          0.681000
# 9915    7    -5.902     1       0.0262       0.19000          0.000931
# 9916    6    -5.739     1       0.0380       0.00824          0.002080
# 9917    1    -3.440     1       0.2640       0.00767          0.110000
#
#       liveness  valence    tempo  \
# 0       0.1130    0.122   95.360
# 1       0.1280    0.648  151.277
# 2       0.1110    0.223  123.753
# 3       0.3100    0.960  129.649
# 4       0.0919    0.385  116.755
# ...        ...      ...      ...
# 9913    0.0825    0.776  133.769
# 9914    0.0572    0.990  139.787
# 9915    0.0710    0.766   80.567
# 9916    0.0732    0.688  117.071
# 9917    0.9480    0.315  199.962
#
#                                              track_href  \
# 0     https://api.spotify.com/v1/tracks/33xMbeHzmWd6...
# 1     https://api.spotify.com/v1/tracks/3UnyplmZaq54...
# 2     https://api.spotify.com/v1/tracks/1w8QCSDH4Qob...
# 3     https://api.spotify.com/v1/tracks/7J9mBHG4J2eI...
# 4     https://api.spotify.com/v1/tracks/1VZedwJj1gyi...
# ...                                                 ...
# 9913  https://api.spotify.com/v1/tracks/5jzma6gCzYtK...
# 9914  https://api.spotify.com/v1/tracks/2fmMPJb5EzZC...
# 9915  https://api.spotify.com/v1/tracks/60rIdEPDrzyL...
# 9916  https://api.spotify.com/v1/tracks/0sEm1ld0V8YT...
# 9917  https://api.spotify.com/v1/tracks/4JPE3Q7vuFa6...
#
#                                            analysis_url
# 0     https://api.spotify.com/v1/audio-analysis/33xM...
# 1     https://api.spotify.com/v1/audio-analysis/3Uny...
# 2     https://api.spotify.com/v1/audio-analysis/1w8Q...
# 3     https://api.spotify.com/v1/audio-analysis/7J9m...
# 4     https://api.spotify.com/v1/audio-analysis/1VZe...
# ...                                                 ...
# 9913  https://api.spotify.com/v1/audio-analysis/5jzm...
# 9914  https://api.spotify.com/v1/audio-analysis/2fmM...
# 9915  https://api.spotify.com/v1/audio-analysis/60rI...
# 9916  https://api.spotify.com/v1/audio-analysis/0sEm...
# 9917  https://api.spotify.com/v1/audio-analysis/4JPE...
#
# [9918 rows x 19 columns]

# %%
dfc = df.drop(['title', 'artist', 'duration_ms', 'explicit','popularity', 'uri', 'track_href', 'analysis_url'], axis=1)

# %%
#dfc['explicit'] = dfc['explicit'].astype(int)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler().fit(dfc)
dfc_scaled = scaler.transform(dfc)

# %%
pd.DataFrame(dfc_scaled, columns= dfc.columns)
# Out:
#       danceability    energy       key  loudness      mode  speechiness  \
# 0        -1.623221 -0.738529  0.500947 -1.206181 -1.358643     0.162297
# 1        -0.936749 -0.226422 -0.055767 -0.789792  0.736028    -0.463909
# 2        -1.346113 -1.348789  1.057661 -1.141745  0.736028    -0.489395
# 3         1.003006  0.712440 -0.055767  0.340275 -1.358643    -0.153234
# 4         0.020533  0.452119 -1.447552  0.512414  0.736028    -0.569491
# ...            ...       ...       ...       ...       ...          ...
# 9913      0.524365  0.780721 -1.447552  0.193027  0.736028    -0.261242
# 9914      1.532031  0.123517 -1.447552 -0.655803  0.736028    -0.280659
# 9915      0.744792 -0.034382  0.500947  0.527534  0.736028    -0.567063
# 9916      0.902240  0.426514  0.222590  0.565451  0.736028    -0.423861
# 9917     -1.541348  1.617161 -1.169195  1.100244  0.736028     2.318824
#
#       acousticness  instrumentalness  liveness   valence     tempo
# 0        -0.625271         -0.193407 -0.482050 -1.466062 -0.872056
# 1        -0.489192          0.835855 -0.390380  0.656264  1.075797
# 2         0.944391         -0.181554 -0.494273 -1.058543  0.117006
# 3         0.105761          0.029115  0.721880  1.915134  0.322392
# 4        -0.849644         -0.440743 -0.610999 -0.404899 -0.126767
# ...            ...               ...       ...       ...       ...
# 9913     -0.533497         -0.452634 -0.668445  1.172724  0.465911
# 9914     -0.662298          2.151107 -0.823061  2.036180  0.675546
# 9915     -0.321466         -0.449075 -0.738725  1.132375 -1.387366
# 9916     -0.896671         -0.444681 -0.725280  0.817658 -0.115759
# 9917     -0.898475         -0.032059  4.620901 -0.687338  2.771726
#
# [9918 rows x 11 columns]

# %%
import numpy as np
import matplotlib.pyplot as plt

from sklearn import cluster, datasets
from sklearn.preprocessing import StandardScaler
from matplotlib.lines import Line2D
from sklearn.cluster import KMeans


K = range(2, 20)
inertia = []

for k in K:
    kmeans = KMeans(n_clusters=k,
                    random_state=1234)
    kmeans.fit(dfc_scaled)
    inertia.append(kmeans.inertia_)

import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(figsize=(16,8))
plt.plot(K, inertia, 'bx-')
plt.xlabel('k')
plt.ylabel('inertia')
plt.xticks(np.arange(min(K), max(K)+1, 1.0))
plt.title('Elbow Method showing the optimal k')
# Out:
# Text(0.5, 1.0, 'Elbow Method showing the optimal k')

# %%
from sklearn.metrics import silhouette_score
K = range(2, 20)
silhouette = []

for k in K:
    kmeans = KMeans(n_clusters=k,
                    random_state=1234)
    kmeans.fit(dfc_scaled)
    silhouette.append(silhouette_score(dfc_scaled, kmeans.predict(dfc_scaled)))


plt.figure(figsize=(16,8))
plt.plot(K, silhouette, 'bx-')
plt.xlabel('k')
plt.ylabel('silhouette score')
plt.xticks(np.arange(min(K), max(K)+1, 1.0))
plt.title('Slhouette score showing the optimal k')
# Out:
# Text(0.5, 1.0, 'Slhouette score showing the optimal k')

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=7, random_state=1234)
kmeans.fit(dfc_scaled)
# Out:
# KMeans(n_clusters=7, random_state=1234)

# %%
clusters = kmeans.predict(dfc_scaled)

# Check the size of the clusters
pd.Series(clusters).value_counts().sort_index()
# Out:
# 0     814
# 1    2127
# 2    3412
# 3     450
# 4     570
# 5     601
# 6    1944
# dtype: int64

# %%
# kaggle = pd.read_csv('SpotifyAudioFeaturesApril2019.csv')
# ggle = kaggle.drop(['artist_name','track_id', 'track_name'], axis=1)
# from sklearn.preprocessing import StandardScaler
# kaggle_scl = StandardScaler().fit_transform(kaggle)
# pd.DataFrame(kaggle_scl, columns= kaggle.columns)
# import numpy as np
# import matplotlib.pyplot as plt

# from sklearn import cluster, datasets
# from sklearn.preprocessing import StandardScaler
# from matplotlib.lines import Line2D
# from sklearn.cluster import KMeans


# K = range(2, 20)
# inertia = []

# for k in K:
#     kmeans = KMeans(n_clusters=k,
#                     random_state=1234)
#     kmeans.fit(kaggle_scl)
#     inertia.append(kmeans.inertia_)

# import matplotlib.pyplot as plt
# %matplotlib inline

# plt.figure(figsize=(16,8))
# plt.plot(K, inertia, 'bx-')
# plt.xlabel('k')
# plt.ylabel('inertia')
# plt.xticks(np.arange(min(K), max(K)+1, 1.0))
# plt.title('Elbow Method showing the optimal k')

# %%
cluster = pd.DataFrame(clusters, columns = ['clusters'])

# %%
df_clustered = pd.concat([df, cluster], axis=1)

# %%
hits = pd.read_csv('hits.csv')

# %%
import random 
song_artist = input("What song or artist do you like?: ").lower()


if song_artist in list(hits['title']):
    print(random.choice(list(hits['title']+' by- '+hits['artist'])))
elif song_artist in list(hits['artist']):
    print(random.choice(list(hits['artist'])))
else:
    print('We cannot give you a recomendation yet')
# Out:
# What song or artist do you like?: rn
# We cannot give you a recomendation yet

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
secrets_file = open("secrets.txt","r")

# %%
string = secrets_file.read()

# %%
string.split('\n')
# Out:
# ['cid:fa7c9c903811431da7ecfeedbcd274e8',
#  'cdd:a206016bf4244fceafe52a076669d594']

# %%
secrets_dict={}
for line in string.split('\n'):
    if len(line) > 0:
        secrets_dict[line.split(':')[0]]=line.split(':')[1]

# %%
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=secrets_dict['cid'],
                                                           client_secret=secrets_dict['cdd']))

# %%
results = sp.search(q='lady madrid', limit=1)
results
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=lady+madrid&type=track&offset=0&limit=1',
#   'items': [{'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6mfK6Q2tzLMEchAr0e9Uzu'},
#        'href': 'https://api.spotify.com/v1/artists/6mfK6Q2tzLMEchAr0e9Uzu',
#        'id': '6mfK6Q2tzLMEchAr0e9Uzu',
#        'name': 'Pereza',
#        'type': 'artist',
#        'uri': 'spotify:artist:6mfK6Q2tzLMEchAr0e9Uzu'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5E2LBAl6sq7k4TdAPqSCMH'},
#      'href': 'https://api.spotify.com/v1/albums/5E2LBAl6sq7k4TdAPqSCMH',
#      'id': '5E2LBAl6sq7k4TdAPqSCMH',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27397a794492257515c4d6d601e',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0297a794492257515c4d6d601e',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485197a794492257515c4d6d601e',
#        'width': 64}],
#      'name': 'Aviones',
#      'release_date': '2009-08-25',
#      'release_date_precision': 'day',
#      'total_tracks': 17,
#      'type': 'album',
#      'uri': 'spotify:album:5E2LBAl6sq7k4TdAPqSCMH'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6mfK6Q2tzLMEchAr0e9Uzu'},
#       'href': 'https://api.spotify.com/v1/artists/6mfK6Q2tzLMEchAr0e9Uzu',
#       'id': '6mfK6Q2tzLMEchAr0e9Uzu',
#       'name': 'Pereza',
#       'type': 'artist',
#       'uri': 'spotify:artist:6mfK6Q2tzLMEchAr0e9Uzu'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 191586,
#     'explicit': False,
#     'external_ids': {'isrc': 'ES5020900283'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5NQw5WJwKRPaaSDHXD04Fs'},
#     'href': 'https://api.spotify.com/v1/tracks/5NQw5WJwKRPaaSDHXD04Fs',
#     'id': '5NQw5WJwKRPaaSDHXD04Fs',
#     'is_local': False,
#     'name': 'Lady Madrid',
#     'popularity': 59,
#     'preview_url': 'https://p.scdn.co/mp3-preview/e85396a49ee7e4e368b868755837a4434f46ab25?cid=fa7c9c903811431da7ecfeedbcd274e8',
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:5NQw5WJwKRPaaSDHXD04Fs'}],
#   'limit': 1,
#   'next': 'https://api.spotify.com/v1/search?query=lady+madrid&type=track&offset=1&limit=1',
#   'offset': 0,
#   'previous': None,
#   'total': 63}}

# %%
results["tracks"]["items"][0]["name"]
# Out:
# 'Lady Madrid'

# %%
song_uri = results["tracks"]["items"][0]["uri"]

# %%
audio_features = sp.audio_features(song_uri)

# %%
audio_features = pd.DataFrame.from_dict(data = audio_features, orient = 'columns')

# %%
audio_features = audio_features.drop(['type', 'id', 'uri', 'track_href', 'analysis_url', 'duration_ms', 'time_signature'], axis=1)

# %%
audio_features
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.598   0.655    0    -2.761     1       0.0256         0.359
#
#    instrumentalness  liveness  valence    tempo
# 0                 0    0.0922    0.377  115.041

# %%
audio_features = scaler.transform(audio_features)

# %%
audio_features
# Out:
# array([[ 0.19057639,  0.15765769, -1.44755172,  1.25819296,  0.73602847,
#         -0.57434495,  0.21335874, -0.4526341 , -0.60916534, -0.43717777,
#         -0.18647395]])

# %%
song_prep_clus = kmeans.predict(audio_features)

# %%
song_prep_clus
# Out:
# array([2])

# %%
print(random.choice(list(df_clustered['title'][df_clustered['clusters']== song_prep_clus[0]])))
# Out:
# Feelin' Alright

# %%
df_clustered[df_clustered['title']== "She's A Rainbow"]
# Out:
#                 title              artist  duration_ms  explicit  popularity  \
# 5732  She's A Rainbow  The Rolling Stones       251586     False           0
#
#                                        uri  danceability  energy  key  \
# 5732  spotify:track:7H3mpx2b0wEsRiuEv7xaL2         0.466   0.712   10
#
#       loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 5732   -11.911     1       0.0357         0.424            0.0171      0.36
#
#       valence    tempo                                         track_href  \
# 5732    0.533  109.141  https://api.spotify.com/v1/tracks/7H3mpx2b0wEs...
#
#                                            analysis_url  clusters
# 5732  https://api.spotify.com/v1/audio-analysis/7H3m...         2

# %%
import random 
song = input("What song or artist do you like?: ").lower()


if song in list(hits['title']):
    print(random.choice(list(hits['title']+' by- '+hits['artist'])))
else:
    results = sp.search(q= song, limit=1)
    song_uri = results["tracks"]["items"][0]["uri"]
    audio_features = sp.audio_features(song_uri)
    audio_features = pd.DataFrame.from_dict(data = audio_features, orient = 'columns')
    audio_features = audio_features.drop(['type', 'id', 'uri', 'track_href', 'analysis_url', 'duration_ms', 'time_signature'], axis=1)
    audio_features = scaler.transform(audio_features)
    song_prep_clus = kmeans.predict(audio_features)
    print('We recommend you listen to: ', random.choice(list(df_clustered['title'][df_clustered['clusters']== song_prep_clus[0]])))
# Out:
# What song or artist do you like?: lady madrid
# We recommend you listen to:  I Want to Hold Your Hand

# %%
df_clustered[df_clustered['title']== "I Want to Hold Your Hand"]
# Out:
#                          title    artist  duration_ms  explicit  popularity  \
# 1377  I Want to Hold Your Hand  Rita Lee       138306     False          30
#
#                                        uri  danceability  energy  key  \
# 1377  spotify:track:2SUpzoAoP6yENHO5mpffKS         0.692   0.576    7
#
#       loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 1377    -7.961     1       0.0321        0.0108          0.000013     0.148
#
#       valence   tempo                                         track_href  \
# 1377    0.562  138.95  https://api.spotify.com/v1/tracks/2SUpzoAoP6yE...
#
#                                            analysis_url  clusters
# 1377  https://api.spotify.com/v1/audio-analysis/2SUp...         2
